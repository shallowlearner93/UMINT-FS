# %%
import sys
sys.path.append('/home/chayan/UMINTFS/')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi
from utills import ComparisonPlot as CP

sns.set_theme(style="whitegrid")

# %%
Acc = pd.ExcelFile("cbmc8k_comp.xlsx").parse("Accuracy",index_col=0)
F1 = pd.ExcelFile("cbmc8k_comp.xlsx").parse("F1_Score",index_col=0)

# %%
Acc
# Out:
#          neighbour 5  neighbour 15  neighbour 25  neighbour 35  neighbour 45
# UMINTFS     0.854988      0.864269      0.862529      0.854988      0.856148
# MUON        0.816705      0.827726      0.833527      0.832947      0.834687
# Seurat      0.817285      0.832367      0.822506      0.820766      0.817285

# %%
print(Acc.min().min(), Acc.max().max())
# Out:
# 0.816705 0.864269

# %%
yticks = [0.79,0.83,0.87]
ylabel = [str(i) for i in yticks]
ylim = [0.78,0.87]
label = Acc.index
col = ['#4c72b0', '#dd8452', '#55a868']

# %%
path = 'figures/cbmc8k_acc_comp.eps'
sns.set_theme()
CP.SpiderPlot(Acc, yticks, ylabel, ylim, label, col, path)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
F1
# Out:
#          neighbour 5  neighbour 15  neighbour 25  neighbour 35  neighbour 45
# UMINTFS     0.847092      0.855053      0.852032      0.842873      0.841466
# MUON        0.807328      0.817403      0.822336      0.820212      0.829350
# Seurat      0.814494      0.829195      0.817210      0.813087      0.809512

# %%
print(F1.min().min(), F1.max().max())
# Out:
# 0.807328 0.855053

# %%
yticks = [0.78,0.82,0.86]
ylabel = [str(i) for i in yticks]
ylim = [0.78,0.86]
label = F1.index
col = ['#4c72b0', '#dd8452', '#55a868']

# %%
path = 'figures/cbmc8k_f1_comp.eps'
sns.set_theme()
CP.SpiderPlot(F1, yticks, ylabel, ylim, label, col, path)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
