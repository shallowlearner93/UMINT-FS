# %%
import sys
sys.path.append('/home/chayan/UMINTFS/')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi
from utills import ComparisonPlot as CP

sns.set_theme(style="whitegrid")

# %%
Acc = pd.ExcelFile("pbmc10k_atac_comp.xlsx").parse("Accuracy",index_col=0)
F1 = pd.ExcelFile("pbmc10k_atac_comp.xlsx").parse("F1_Score",index_col=0)

# %%
Acc
# Out:
#          neighbour 5  neighbour 15  neighbour 25  neighbour 35  neighbour 45
# UMINTFS     0.924653      0.926636      0.927958      0.927297      0.926636
# MUON        0.894911      0.898876      0.894911      0.896233      0.895572
# Seurat      0.916722      0.916061      0.917383      0.910773      0.907469

# %%
print(Acc.min().min(), Acc.max().max())
# Out:
# 0.894911 0.927958

# %%
yticks = [0.87,0.90,0.93]
ylabel = [str(i) for i in yticks]
ylim = [0.87,0.93]
label = Acc.index
col = ['#4c72b0', '#dd8452', '#55a868']

# %%
path = 'figures/pbmc10k_atac_acc_comp.eps'
sns.set_theme()
CP.SpiderPlot(Acc, yticks, ylabel, ylim, label, col, path)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
F1
# Out:
#          neighbour 5  neighbour 15  neighbour 25  neighbour 35  neighbour 45
# UMINTFS     0.924771      0.926573      0.927824      0.927123      0.926413
# MUON        0.893449      0.897412      0.893155      0.894373      0.893647
# Seurat      0.917389      0.916742      0.917797      0.911416      0.908116

# %%
print(F1.min().min(), F1.max().max())
# Out:
# 0.893155 0.927824

# %%
yticks = [0.87,0.90,0.93]
ylabel = [str(i) for i in yticks]
ylim = [0.87,0.93]
label = F1.index
col = ['#4c72b0', '#dd8452', '#55a868']

# %%
path = 'figures/pbmc10k_atac_f1_comp.eps'
sns.set_theme()
CP.SpiderPlot(F1, yticks, ylabel, ylim, label, col, path)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
